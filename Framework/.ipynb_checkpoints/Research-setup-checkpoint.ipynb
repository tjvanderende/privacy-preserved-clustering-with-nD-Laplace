# %%
import os, sys
dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)<cite data-cite="6250197/EC9DN7NT"></cite>
if not dir1 in sys.path: sys.path.append(dir1)
from Helpers import helpers
import numpy as np

# %% [markdown]
# <div class="cite2c-biblio"></div><div class="cite2c-biblio"></div>## Research setup
# First we import the dataset as CSV to a pandas DataFrame

# %%
[airline_training, airline_data] = helpers.import_dasaset('../data/airline-dataset.zip')
airline = airline_training + airline_data
airline.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  25976.000000   25976.000000  25976.000000     25976.000000
# mean   25975.000000  129703.929050     78.822490      2385.042154
# std    14997.539265   52938.756872     21.307753      1415.621017
# min        0.000000    1320.000000     15.000000       153.000000
# 25%    12987.500000   92038.250000     64.000000      1225.750000
# 50%    25975.000000  129730.500000     79.000000      2101.000000
# 75%    38962.500000  167129.500000     94.000000      3324.000000
# max    51950.000000  259103.000000    153.000000      7953.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           25976.000000                       25976.000000
# mean                5.457730                           6.108100
# std                 1.880671                           2.167291
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# For the purpose of our study, we only consider numeric features.

# %%
airline_numeric = airline.select_dtypes(include=np.number)
