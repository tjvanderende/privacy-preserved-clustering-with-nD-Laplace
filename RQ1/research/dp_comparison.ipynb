# %%
import sys 
sys.path.append('../../')

# %%
import Helpers.helpers as helpers
results = helpers.load_dataset('./../export/seeds_dataset/utility_scores/comparison-utility.csv')
results.head()
# Out:
# /opt/conda/lib/python3.9/site-packages/art/estimators/certification/__init__.py:14: UserWarning: PyTorch not found. Not importing DeepZ or Interval Bound Propagation functionality
#   warnings.warn("PyTorch not found. Not importing DeepZ or Interval Bound Propagation functionality")
#        type  epsilon       ari       ami          ch        sc
# 0  Pairwise     0.05 -0.002782 -0.002506  165.149538  0.382959
# 1  Pairwise     0.05 -0.002575 -0.002262  165.393588  0.382915
# 2  Pairwise     0.10  0.004754  0.004720  194.343861  0.422113
# 3  Pairwise     0.10  0.006436  0.006257  194.145510  0.421371
# 4  Pairwise     0.50 -0.004070 -0.003639  154.121776  0.375562

# %%
import seaborn as sns
sns.barplot(x="epsilon", y="ami", hue="type", data=results)
# Out:
# <AxesSubplot:xlabel='epsilon', ylabel='ami'>

# %%
sns.barplot(x="epsilon", y="ari", hue="type", data=results)
# Out:
# <AxesSubplot:xlabel='epsilon', ylabel='ari'>

# %%
sns.barplot(x="epsilon", y="sc", hue="type", data=results)
# Out:
# <AxesSubplot:xlabel='epsilon', ylabel='sc'>

# %%
sns.barplot(x="epsilon", y="ch", hue="type", data=results)
# Out:
# <AxesSubplot:xlabel='epsilon', ylabel='ch'>

# %%
results_privacy = helpers.load_dataset('./../export/privacy_scores/privacy-dp-comparison.csv')
results_privacy.head()
# Out:
#    epsilon  shokri_mi_adv  run      type
# 0     0.05          0.148    0  Gaussian
# 1     0.05          0.144    1  Gaussian
# 2     0.05          0.188    2  Gaussian
# 3     0.05          0.236    3  Gaussian
# 4     0.05          0.216    4  Gaussian

# %%
sns.barplot(x="epsilon", y="shokri_mi_adv", hue="type", data=results_privacy)
# Out:
# <AxesSubplot:xlabel='epsilon', ylabel='shokri_mi_adv'>

# %%
import numpy as np


def duchi_1d(t_i:float,e:float):
    #Calculate p for bernoulli variable
    p = ((np.exp(e)-1)/(2*np.exp(e)+2))*t_i + 1/2
    #Random sample for bernoulli(p)
    u = np.random.binomial(1,p)
    print(u, p)
    #t_i with noise added
    if(u==1):
        t_i_out = (np.exp(e)+1)/(np.exp(e)-1)
    else:
        t_i_out = -(np.exp(e)+1)/(np.exp(e)-1)
    return t_i_out

duchi_1d(2,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_820/1928019593.py in <module>
#      15     return t_i_out
#      16
# ---> 17 duchi_1d(2,2)
#
# /tmp/ipykernel_820/1928019593.py in duchi_1d(t_i, e)
#       6     p = ((np.exp(e)-1)/(2*np.exp(e)+2))*t_i + 1/2
#       7     #Random sample for bernoulli(p)
# ----> 8     u = np.random.binomial(1,p)
#       9     print(u, p)
#      10     #t_i with noise added
#
# mtrand.pyx in numpy.random.mtrand.RandomState.binomial()
#
# _common.pyx in numpy.random._common.check_constraint()
#
# ValueError: p < 0, p > 1 or p is NaN
